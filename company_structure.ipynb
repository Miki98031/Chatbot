# %%
import tkinter as tk

class MovableTextBox:
    def __init__(self, root, text="Move me!", x=50, y=50):
        self.root = root
        self.text = text
        self.x = x
        self.y = y

        # Create canvas
        self.canvas = tk.Canvas(root, width=600, height=600, bg="white")
        self.canvas.pack()

        # Create text box
        self.text_box = self.canvas.create_text(self.x, self.y, text=self.text, anchor="nw", tags="text_box")

        # Bind events for moving the text box
        self.canvas.tag_bind("text_box", "<B1-Motion>", self.on_drag)

    def on_drag(self, event):
        # Update text box position on drag
        self.x = event.x
        self.y = event.y
        self.canvas.coords(self.text_box, self.x, self.y)

if __name__ == "__main__":
    root = tk.Tk()
    root.title("Movable Text Box")

    movable_text_box = MovableTextBox(root)

    root.mainloop()

# %%
import tkinter as tk

class MovableTextBox:
    def __init__(self, canvas, text="Move me!", x=50, y=50):
        self.canvas = canvas
        self.text = text
        self.x = x
        self.y = y

        # Create text box on the canvas
        self.text_box = self.canvas.create_text(self.x, self.y, text=self.text, anchor="nw", tags="text_box")

        # Bind events for moving the text box
        self.canvas.tag_bind("text_box", "<B1-Motion>", self.on_drag)

    def on_drag(self, event):
        # Update text box position on drag
        self.x = event.x
        self.y = event.y
        self.canvas.coords(self.text_box, self.x, self.y)

class MovableTextApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Movable Text App")

        # Create canvas
        self.canvas = tk.Canvas(root, width=500, height=300, bg="white")
        self.canvas.pack()

        # Create a list to store movable text boxes
        self.text_boxes = []

        # Bind click event to add a new text box
        self.canvas.bind("<Button-1>", self.add_text_box)

    def add_text_box(self, event):
        # Create a new movable text box and add it to the list
        new_text_box = MovableTextBox(self.canvas, text="Move me!", x=event.x, y=event.y)
        self.text_boxes.append(new_text_box)

if __name__ == "__main__":
    root = tk.Tk()
    app = MovableTextApp(root)
    root.mainloop()

# %%
import tkinter as tk

class MovableTextBox:
    def __init__(self, canvas, text="Move me!", x=50, y=50):
        self.canvas = canvas
        self.text = text
        self.x = x
        self.y = y

        # Create text box on the canvas
        self.text_box = self.canvas.create_text(self.x, self.y, text=self.text, anchor="nw", tags="text_box")

        # Bind events for moving the text box
        self.canvas.tag_bind("text_box", "<B1-Motion>", self.on_drag)

    def on_drag(self, event):
        # Update text box position on drag
        self.x = event.x
        self.y = event.y
        self.canvas.coords(self.text_box, self.x, self.y)

class MovableTextApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Movable Text App")

        # Create canvas
        self.canvas = tk.Canvas(root, width=600, height=600, bg="white")
        self.canvas.pack()

        # Create a list to store movable text boxes
        self.text_boxes = []

        # Create a list to store connecting lines
        self.lines = []

        # Bind click event to add a new text box
        self.canvas.bind("<Button-1>", self.add_text_box)

        # Bind motion event to update connecting lines
        self.canvas.bind("<B1-Motion>", self.update_lines)

    def add_text_box(self, event):
        # Create a new movable text box and add it to the list
        new_text_box = MovableTextBox(self.canvas, text="Move me!", x=event.x, y=event.y)
        self.text_boxes.append(new_text_box)

    def update_lines(self, event):
        # Update connecting lines between text boxes
        for line in self.lines:
            self.canvas.delete(line)

        self.lines = []

        for i in range(len(self.text_boxes) - 1):
            x1, y1 = self.text_boxes[i].x, self.text_boxes[i].y
            x2, y2 = self.text_boxes[i + 1].x, self.text_boxes[i + 1].y
            line = self.canvas.create_line(x1, y1, x2, y2, fill="black")
            self.lines.append(line)

if __name__ == "__main__":
    root = tk.Tk()
    app = MovableTextApp(root)
    root.mainloop()

# %%
import tkinter as tk

class MovableTextBox:
    def __init__(self, canvas, text="Move me!", x=50, y=50):
        self.canvas = canvas
        self.text = text
        self.x = x
        self.y = y

        # Create text box on the canvas
        self.text_box = self.canvas.create_text(self.x, self.y, text=self.text, anchor="nw", tags="text_box")

        # Bind events for moving the text box
        self.canvas.tag_bind("text_box", "<B1-Motion>", self.on_drag)

    def on_drag(self, event):
        # Update text box position on drag
        self.x = event.x
        self.y = event.y
        self.canvas.coords(self.text_box, self.x, self.y)

class MovableTextApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Movable Text App")

        # Create canvas
        self.canvas = tk.Canvas(root, width=500, height=300, bg="white")
        self.canvas.pack()

        # Create a list to store movable text boxes
        self.text_boxes = []

        # Create a list to store connecting lines
        self.lines = []

        # Create buttons
        self.create_button = tk.Button(root, text="Create Movable Text Box", command=self.add_text_box)
        self.create_button.pack(pady=10)

        self.connect_button = tk.Button(root, text="Connect Text Boxes", command=self.update_lines)
        self.connect_button.pack(pady=10)

        # Bind motion event to update connecting lines
        self.canvas.bind("<B1-Motion>", self.update_lines)

    def add_text_box(self):
        # Create a new movable text box and add it to the list
        new_text_box = MovableTextBox(self.canvas, text="Move me!", x=50, y=50)
        self.text_boxes.append(new_text_box)

    def update_lines(self, event=None):
        # Update connecting lines between text boxes
        for line in self.lines:
            self.canvas.delete(line)

        self.lines = []

        for i in range(len(self.text_boxes) - 1):
            x1, y1 = self.text_boxes[i].x, self.text_boxes[i].y
            x2, y2 = self.text_boxes[i + 1].x, self.text_boxes[i + 1].y
            line = self.canvas.create_line(x1, y1, x2, y2, fill="black")
            self.lines.append(line)

if __name__ == "__main__":
    root = tk.Tk()
    app = MovableTextApp(root)
    root.mainloop()

# %%
import tkinter as tk

class MovableTextBox:
    def __init__(self, canvas, text="Move me!", x=50, y=50):
        self.canvas = canvas
        self.text = text
        self.x = x
        self.y = y

        # Create text box on the canvas
        self.text_box = self.canvas.create_text(self.x, self.y, text=self.text, anchor="nw", tags="text_box")

        # Bind events for moving the text box
        self.canvas.tag_bind("text_box", "<B1-Motion>", self.on_drag)

    def on_drag(self, event):
        # Update text box position on drag
        self.x = event.x
        self.y = event.y
        self.canvas.coords(self.text_box, self.x, self.y)

class MovableTextApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Movable Text App")

        # Create canvas
        self.canvas = tk.Canvas(root, width=500, height=300, bg="white")
        self.canvas.pack()

        # Create a list to store movable text boxes
        self.text_boxes = []

        # Create a list to store connecting lines
        self.lines = []

        # Create buttons
        self.create_button = tk.Button(root, text="Create Movable Text Box", command=self.add_text_box)
        self.create_button.pack(pady=10)

        self.connect_button = tk.Button(root, text="Connect Text Boxes", command=self.connect_text_boxes)
        self.connect_button.pack(pady=10)

        # Bind motion event to update connecting lines
        self.canvas.bind("<B1-Motion>", self.update_lines)

        # Variable to track whether to connect text boxes on click
        self.connect_on_click = False

    def add_text_box(self):
        # Create a new movable text box and add it to the list
        new_text_box = MovableTextBox(self.canvas, text="Move me!", x=50, y=50)
        self.text_boxes.append(new_text_box)

    def connect_text_boxes(self):
        # Set the flag to connect text boxes on click
        self.connect_on_click = not self.connect_on_click

    def update_lines(self, event=None):
        # Update connecting lines between text boxes only if the flag is set
        if self.connect_on_click:
            for line in self.lines:
                self.canvas.delete(line)

            self.lines = []

            for i in range(len(self.text_boxes) - 1):
                x1, y1 = self.text_boxes[i].x, self.text_boxes[i].y
                x2, y2 = self.text_boxes[i + 1].x, self.text_boxes[i + 1].y
                line = self.canvas.create_line(x1, y1, x2, y2, fill="black")
                self.lines.append(line)

if __name__ == "__main__":
    root = tk.Tk()
    app = MovableTextApp(root)
    root.mainloop()

# %%
import tkinter as tk

class MovableTextBox:
    def __init__(self, canvas, text="Move me!", x=50, y=50):
        self.canvas = canvas
        self.text = text
        self.x = x
        self.y = y

        # Create text box on the canvas
        self.text_box = self.canvas.create_text(self.x, self.y, text=self.text, anchor="nw", tags="text_box")

        # Bind events for moving the text box
        self.canvas.tag_bind("text_box", "<B1-Motion>", self.on_drag)

    def on_drag(self, event):
        # Update text box position on drag
        self.x = event.x
        self.y = event.y
        self.canvas.coords(self.text_box, self.x, self.y)

class MovableTextApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Movable Text App")

        # Create canvas
        self.canvas = tk.Canvas(root, width=500, height=300, bg="white")
        self.canvas.pack()

        # Create a list to store movable text boxes
        self.text_boxes = []

        # Create a list to store connecting lines
        self.lines = []

        # Create buttons
        self.create_button = tk.Button(root, text="Create Movable Text Box", command=self.add_text_box)
        self.create_button.pack(pady=10)

        self.connect_button = tk.Button(root, text="Connect Text Boxes", command=self.connect_text_boxes)
        self.connect_button.pack(pady=10)

        # Bind motion event to update connecting lines
        self.canvas.bind("<B1-Motion>", self.update_lines)

        # Variable to track whether to connect text boxes on click
        self.connect_on_click = False

        # Variable to track text box clicks for connecting
        self.connecting_text_boxes = []

    def add_text_box(self):
        # Create a new movable text box and add it to the list
        new_text_box = MovableTextBox(self.canvas, text="Move me!", x=50, y=50)
        self.text_boxes.append(new_text_box)

    def connect_text_boxes(self):
        # Set the flag to connect text boxes on click
        self.connect_on_click = not self.connect_on_click
        # Clear the list of connecting text boxes
        self.connecting_text_boxes = []

    def update_lines(self, event=None):
        # Update connecting lines between text boxes only if the flag is set
        if self.connect_on_click:
            # Check if a text box is clicked
            for text_box in self.text_boxes:
                x1, y1, _, _ = self.canvas.bbox(text_box.text_box)
                if x1 <= event.x <= x1 + 10 and y1 <= event.y <= y1 + 10:
                    # If a text box is clicked, add it to the connecting list
                    self.connecting_text_boxes.append(text_box)

            # Draw a line between the first two text boxes in the connecting list
            if len(self.connecting_text_boxes) >= 2:
                text_box1 = self.connecting_text_boxes.pop(0)
                text_box2 = self.connecting_text_boxes.pop(0)

                x1, y1 = text_box1.x, text_box1.y
                x2, y2 = text_box2.x, text_box2.y
                line = self.canvas.create_line(x1, y1, x2, y2, fill="black")
                self.lines.append(line)

if __name__ == "__main__":
    root = tk.Tk()
    app = MovableTextApp(root)
    root.mainloop()

# %%
import tkinter as tk

class MovableTextBox:
    def __init__(self, canvas, text="Move me!", x=50, y=50):
        self.canvas = canvas
        self.text = text
        self.x = x
        self.y = y

        # Create text box on the canvas
        self.text_box = self.canvas.create_text(self.x, self.y, text=self.text, anchor="nw", tags="text_box")

        # Bind events for moving the text box
        self.canvas.tag_bind("text_box", "<B1-Motion>", self.on_drag)

        # Bind click event to track text box clicks
        self.canvas.tag_bind("text_box", "<Button-1>", self.on_click)

    def on_drag(self, event):
        # Update text box position on drag
        self.x = event.x
        self.y = event.y
        self.canvas.coords(self.text_box, self.x, self.y)

    def on_click(self, event):
        # Add the clicked text box to the connecting list
        connecting_text_boxes.append(self)

class MovableTextApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Movable Text App")

        # Create canvas
        self.canvas = tk.Canvas(root, width=500, height=300, bg="white")
        self.canvas.pack()

        # Create a list to store movable text boxes
        self.text_boxes = []

        # Create a list to store connecting lines
        self.lines = []

        # Create buttons
        self.create_button = tk.Button(root, text="Create Movable Text Box", command=self.add_text_box)
        self.create_button.pack(pady=10)

        self.connect_button = tk.Button(root, text="Connect Text Boxes", command=self.connect_text_boxes)
        self.connect_button.pack(pady=10)

        # Variable to track text box clicks for connecting
        self.connecting_text_boxes = []

    def add_text_box(self):
        # Create a new movable text box and add it to the list
        new_text_box = MovableTextBox(self.canvas, text="Move me!", x=50, y=50)
        self.text_boxes.append(new_text_box)

    def connect_text_boxes(self):
        # Draw a line between the first two text boxes in the connecting list
        if len(self.connecting_text_boxes) >= 2:
            text_box1 = self.connecting_text_boxes.pop(0)
            text_box2 = self.connecting_text_boxes.pop(0)

            x1, y1 = text_box1.x, text_box1.y
            x2, y2 = text_box2.x, text_box2.y
            line = self.canvas.create_line(x1, y1, x2, y2, fill="black")
            self.lines.append(line)

if __name__ == "__main__":
    root = tk.Tk()
    app = MovableTextApp(root)
    root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\mihai\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\mihai\AppData\Local\Temp\ipykernel_12024\1761507999.py", line 27, in on_click
#     connecting_text_boxes.append(self)
#     ^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'connecting_text_boxes' is not defined

# %%
import tkinter as tk

class MovableTextBox:
    def __init__(self, canvas, text="Move me!", x=50, y=50):
        self.canvas = canvas
        self.text = text
        self.x = x
        self.y = y

        # Create text box on the canvas
        self.text_box = self.canvas.create_text(self.x, self.y, text=self.text, anchor="nw", tags="text_box")

        # Bind events for moving the text box
        self.canvas.tag_bind("text_box", "<B1-Motion>", self.on_drag)

        # Bind click event to track text box clicks
        self.canvas.tag_bind("text_box", "<Button-1>", self.on_click)

    def on_drag(self, event):
        # Update text box position on drag
        self.x = event.x
        self.y = event.y
        self.canvas.coords(self.text_box, self.x, self.y)

    def on_click(self, event):
        # Add the clicked text box to the connecting list
        app.connecting_text_boxes.append(self)

class MovableTextApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Movable Text App")

        # Create canvas
        self.canvas = tk.Canvas(root, width=500, height=300, bg="white")
        self.canvas.pack()

        # Create a list to store movable text boxes
        self.text_boxes = []

        # Create a list to store connecting lines
        self.lines = []

        # Create buttons
        self.create_button = tk.Button(root, text="Create Movable Text Box", command=self.add_text_box)
        self.create_button.pack(pady=10)

        self.connect_button = tk.Button(root, text="Connect Text Boxes", command=self.connect_text_boxes)
        self.connect_button.pack(pady=10)

        # Variable to track text box clicks for connecting
        self.connecting_text_boxes = []

    def add_text_box(self):
        # Create a new movable text box and add it to the list
        new_text_box = MovableTextBox(self.canvas, text="Move me!", x=50, y=50)
        self.text_boxes.append(new_text_box)

    def connect_text_boxes(self):
        # Draw a line between the first two text boxes in the connecting list
        if len(self.connecting_text_boxes) >= 2:
            text_box1 = self.connecting_text_boxes.pop(0)
            text_box2 = self.connecting_text_boxes.pop(0)

            x1, y1 = text_box1.x, text_box1.y
            x2, y2 = text_box2.x, text_box2.y
            line = self.canvas.create_line(x1, y1, x2, y2, fill="black")
            self.lines.append(line)

if __name__ == "__main__":
    root = tk.Tk()
    app = MovableTextApp(root)
    root.mainloop()

# %%
import tkinter as tk

class MovableTextBox:
    def __init__(self, canvas, app, text="Move me!", x=50, y=50):
        self.canvas = canvas
        self.app = app
        self.text = text
        self.x = x
        self.y = y

        # Create text box on the canvas
        self.text_box = self.canvas.create_text(self.x, self.y, text=self.text, anchor="nw", tags="text_box")

        # Bind events for moving the text box
        self.canvas.tag_bind("text_box", "<B1-Motion>", self.on_drag)

        # Bind click event to track text box clicks
        self.canvas.tag_bind("text_box", "<Button-1>", self.on_click)

    def on_drag(self, event):
        # Update text box position on drag
        self.x = event.x
        self.y = event.y
        self.canvas.coords(self.text_box, self.x, self.y)

    def on_click(self, event):
        # If in connection mode, add the clicked text box to the connecting list
        if self.app.connect_on_click:
            self.app.connecting_text_boxes.append(self)

class MovableTextApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Movable Text App")

        # Create canvas
        self.canvas = tk.Canvas(root, width=500, height=300, bg="white")
        self.canvas.pack()

        # Create a list to store movable text boxes
        self.text_boxes = []

        # Create a list to store connecting lines
        self.lines = []

        # Create buttons
        self.create_button = tk.Button(root, text="Create Movable Text Box", command=self.add_text_box)
        self.create_button.pack(pady=10)

        self.connect_button = tk.Button(root, text="Connect Text Boxes", command=self.toggle_connect_mode)
        self.connect_button.pack(pady=10)

        # Variable to track whether to connect text boxes on click
        self.connect_on_click = False

        # Variable to track text box clicks for connecting
        self.connecting_text_boxes = []

    def add_text_box(self):
        # Create a new movable text box and add it to the list
        new_text_box = MovableTextBox(self.canvas, self, text="Move me!", x=50, y=50)
        self.text_boxes.append(new_text_box)

    def toggle_connect_mode(self):
        # Toggle the flag to connect text boxes on click
        self.connect_on_click = not self.connect_on_click
        # Clear the list of connecting text boxes
        self.connecting_text_boxes = []

    def connect_text_boxes(self):
        # Draw a line between the two clicked text boxes
        if len(self.connecting_text_boxes) == 2:
            text_box1 = self.connecting_text_boxes[0]
            text_box2 = self.connecting_text_boxes[1]

            x1, y1 = text_box1.x, text_box1.y
            x2, y2 = text_box2.x, text_box2.y
            line = self.canvas.create_line(x1, y1, x2, y2, fill="black")
            self.lines.append(line)

if __name__ == "__main__":
    root = tk.Tk()
    app = MovableTextApp(root)
    root.mainloop()

# %%
import tkinter as tk

class MovableTextBox:
    def __init__(self, canvas, app, text="Move me!", x=50, y=50):
        self.canvas = canvas
        self.app = app
        self.text = text
        self.x = x
        self.y = y

        # Create text box on the canvas
        self.text_box = self.canvas.create_text(self.x, self.y, text=self.text, anchor="nw", tags="text_box")

        # Bind events for moving the text box
        self.canvas.tag_bind("text_box", "<B1-Motion>", self.on_drag)

        # Bind click event to track text box clicks
        self.canvas.tag_bind("text_box", "<Button-1>", self.on_click)

    def on_drag(self, event):
        # Update text box position on drag
        self.x = event.x
        self.y = event.y
        self.canvas.coords(self.text_box, self.x, self.y)

    def on_click(self, event):
        # If in connection mode, add the clicked text box to the connecting list
        if self.app.connect_on_click:
            self.app.connecting_text_boxes.append(self)

class MovableTextApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Movable Text App")

        # Create canvas
        self.canvas = tk.Canvas(root, width=500, height=300, bg="white")
        self.canvas.pack()

        # Create a list to store movable text boxes
        self.text_boxes = []

        # Create a list to store connecting lines
        self.lines = []

        # Create buttons
        self.create_button = tk.Button(root, text="Create Movable Text Box", command=self.add_text_box)
        self.create_button.pack(pady=10)

        self.connect_button = tk.Button(root, text="Connect Text Boxes", command=self.toggle_connect_mode)
        self.connect_button.pack(pady=10)

        # Variable to track whether to connect text boxes on click
        self.connect_on_click = False

        # Variable to track text box clicks for connecting
        self.connecting_text_boxes = []

        # Bind drawing events
        root.bind('<ButtonPress-1>', self.draw_line)
        root.bind('<ButtonRelease-1>', self.draw_line)
        self.canvas.old_coords = None

    def add_text_box(self):
        # Create a new movable text box and add it to the list
        new_text_box = MovableTextBox(self.canvas, self, text="Move me!", x=50, y=50)
        self.text_boxes.append(new_text_box)

    def toggle_connect_mode(self):
        # Toggle the flag to connect text boxes on click
        self.connect_on_click = not self.connect_on_click
        # Clear the list of connecting text boxes
        self.connecting_text_boxes = []

    def draw_line(self, event):
        if str(event.type) == 'ButtonPress':
            self.canvas.old_coords = event.x, event.y

        elif str(event.type) == 'ButtonRelease':
            x, y = event.x, event.y
            x1, y1 = self.canvas.old_coords
            line = self.canvas.create_line(x, y, x1, y1, fill="black")
            self.lines.append(line)

    def reset_coords(self, event):
        self.canvas.old_coords = None

if __name__ == "__main__":
    root = tk.Tk()
    app = MovableTextApp(root)
    root.mainloop()

# %%
import tkinter as tk

def draw(event):
    x, y = event.x, event.y
    if canvas.old_coords:
        x1, y1 = canvas.old_coords
        canvas.create_line(x, y, x1, y1)
    canvas.old_coords = x, y

def draw_line(event):

    if str(event.type) == 'ButtonPress':
        canvas.old_coords = event.x, event.y

    elif str(event.type) == 'ButtonRelease':
        x, y = event.x, event.y
        x1, y1 = canvas.old_coords
        canvas.create_line(x, y, x1, y1)

def reset_coords(event):
    canvas.old_coords = None

root = tk.Tk()

canvas = tk.Canvas(root, width=400, height=400)
canvas.pack()
canvas.old_coords = None

root.bind('<ButtonPress-1>', draw_line)
root.bind('<ButtonRelease-1>', draw_line)

root.bind('<B1-Motion>', draw)
root.bind('<ButtonRelease-1>', reset_coords)

root.mainloop()

# %%
from tkinter import *
current = None
def DrawGrid(drawing_area, line_distance):
   for x in range(line_distance,600,line_distance):
       drawing_area.create_line(x, 0, x, 600, fill="#d3d3d3")
   for y in range(line_distance,600,line_distance):
       drawing_area.create_line(0, y, 600, y, fill="#d3d3d3")
def main():
    root = Tk()
    drawing_area = Canvas(root, width=600, height=600, bg='white')
    drawing_area.pack()
    DrawGrid(drawing_area, 10)
    drawing_area.bind("", reset)
    drawing_area.bind("", motion)
    drawing_area.bind("", Mousedown)
    root.mainloop()
def reset(event):
    global current
    current = None
def Mousedown(event):
    global current
    event.widget.focus_set()  # so escape key will work
    if current is None:
        # the new line starts where the user clicked
        x0 = event.x
        y0 = event.y
    else:
        # the new line starts at the end of the previously
        # drawn line
        coords = event.widget.coords(current)
        x0 = coords[2]
        y0 = coords[3]
    # create the new line
    current = event.widget.create_line(x0, y0, event.x, event.y)
def motion(event):
    if current:
        # modify the current line by changing the end coordinates
        # to be the current mouse position
        coords = event.widget.coords(current)
        coords[2] = event.x
        coords[3] = event.y
        event.widget.coords(current, *coords)
main()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[30], line 43
#      41         coords[3] = event.y
#      42         event.widget.coords(current, *coords)
# ---> 43 main()
#
# Cell In[30], line 14, in main()
#      12 DrawGrid(drawing_area, 10)
#      13 #drawing_area.bind("", reset)
# ---> 14 drawing_area.bind("", motion)
#      15 drawing_area.bind("", Mousedown)
#      16 root.mainloop()
#
# File ~\anaconda3\Lib\tkinter\__init__.py:1448, in Misc.bind(self, sequence, func, add)
#    1409 def bind(self, sequence=None, func=None, add=None):
#    1410     """Bind to this widget at event SEQUENCE a call to function FUNC.
#    1411
#    1412     SEQUENCE is a string of concatenated event
#    (...)
#    1445     If FUNC or SEQUENCE is omitted the bound function or list
#    1446     of bound events are returned."""
# ...

# %%
import tkinter as tk
from PIL import ImageTk


root = tk.Tk()

canvas = tk.Canvas(width = 600, height = 400)
canvas.pack(expand = tk.YES, fill = tk.BOTH)


coords = {"x":None,"y":0,"x2":0,"y2":0}
# keep a reference to all lines by keeping them in a list 
lines = []



def click(e):
    
    # define start point for line
    coords["x"] = e.x
    coords["y"] = e.y
        

    # create a line on this point and store it in the list
    l = lines.append(canvas.create_line(coords["x"],coords["y"],coords["x"],coords["y"], width=5, fill='red'))
        
def drag(e):
    # update the coordinates from the event
    coords["x2"] = e.x
    coords["y2"] = e.y
    print(e.x, e.y)
    # Change the coordinates of the last created line to the new coordinates
    l = canvas.coords(lines[-1], coords["x"],coords["y"],coords["x2"],coords["y2"])

    canvas.itemconfigure(l, fill="black")

canvas.bind("<ButtonPress-1>", click)
canvas.bind("<B1-Motion>", drag)
print(coords["x"],coords["y"],coords["x2"],coords["y2"])

root.mainloop()
# Out:
# None 0 0 0
# 219 93
# 224 97
# 225 100
# 227 102
# 228 106
# 231 110
# 233 114
# 235 118
# 235 120
# 236 122
# 236 125
# 237 125
# 237 126
# 238 129
# 238 133
# 239 136
# 239 139
# 240 143
# 240 148
# 240 152
# 242 158
# 242 162
# 243 167
# 243 171
# 244 174
# 244 176
# 245 177
# 245 178
# 245 179
# 245 180
# 248 184
# 252 194
# 254 201
# 258 210
# 261 217
# 263 223
# 266 225
# 267 227
# 268 229
# 269 230
# 270 231
# 272 233
# 281 241
# 290 246
# 297 250
# 302 254
# 305 255
# 415 102
# 411 104
# 405 107
# 399 113
# 393 117
# 385 121
# 376 127
# 361 137
# 344 150
# 329 158
# 307 165
# 283 178
# 261 184
# 243 187
# 224 193
# 207 198
# 188 204
# 168 211
# 155 214
# 141 219
# 127 223
# 112 229
# 100 233
# 90 237
# 83 239
# 77 240
# 74 242
# 72 242
# 71 242
# 107 275
# 116 275
# 128 275
# 145 271
# 157 269
# 173 265
# 193 264
# 218 263
# 248 261
# 274 258
# 301 258
# 326 258
# 350 258
# 372 258
# 392 258
# 403 258
# 409 257
# 418 257
# 427 258
# 432 258
# 437 258
# 440 258
# 443 258
# ...

# %%
import tkinter as tk
from PIL import ImageTk

class MovableTextBox:
    def __init__(self, canvas, app, text="Move me!", x=50, y=50):
        self.canvas = canvas
        self.app = app
        self.text = text
        self.x = x
        self.y = y

        # Create text box on the canvas
        self.text_box = self.canvas.create_text(self.x, self.y, text=self.text, anchor="nw", tags="text_box")

        # Bind events for moving the text box
        self.canvas.tag_bind("text_box", "<B1-Motion>", self.on_drag)

        # Bind click event to track text box clicks
        self.canvas.tag_bind("text_box", "<Button-1>", self.on_click)

    def on_drag(self, event):
        # Update text box position on drag
        self.x = event.x
        self.y = event.y
        self.canvas.coords(self.text_box, self.x, self.y)

    def on_click(self, event):
        # If in connection mode, add the clicked text box to the connecting list
        if self.app.connect_on_click:
            self.app.connecting_text_boxes.append(self)

class MovableTextApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Movable Text App")

        # Create canvas
        self.canvas = tk.Canvas(root, width=600, height=400)
        self.canvas.pack(expand=tk.YES, fill=tk.BOTH)

        # Create a list to store movable text boxes
        self.text_boxes = []

        # Create a list to store connecting lines
        self.lines = []

        # Create buttons
        self.create_button = tk.Button(root, text="Create Movable Text Box", command=self.add_text_box)
        self.create_button.pack(pady=10)

        self.connect_button = tk.Button(root, text="Connect Text Boxes", command=self.toggle_connect_mode)
        self.connect_button.pack(pady=10)

        # Variable to track whether to connect text boxes on click
        self.connect_on_click = False

        # Variable to track text box clicks for connecting
        self.connecting_text_boxes = []

        # Bind drawing events
        self.canvas.bind("<ButtonPress-1>", self.click)
        self.canvas.bind("<B1-Motion>", self.drag)

        # keep a reference to all lines by keeping them in a list
        self.coords = {"x": None, "y": 0, "x2": 0, "y2": 0}
        self.lines = []

    def add_text_box(self):
        # Create a new movable text box and add it to the list
        new_text_box = MovableTextBox(self.canvas, self, text="Move me!", x=50, y=50)
        self.text_boxes.append(new_text_box)

    def toggle_connect_mode(self):
        # Toggle the flag to connect text boxes on click
        self.connect_on_click = not self.connect_on_click
        # Clear the list of connecting text boxes
        self.connecting_text_boxes = []

    def draw_line(self):
        # Draw a line between the two clicked text boxes
        if len(self.connecting_text_boxes) == 2:
            text_box1 = self.connecting_text_boxes[0]
            text_box2 = self.connecting_text_boxes[1]

            x1, y1 = text_box1.x, text_box1.y
            x2, y2 = text_box2.x, text_box2.y
            line = self.canvas.create_line(x1, y1, x2, y2, fill="black")
            self.lines.append(line)

    def click(self, event):
        # define start point for line
        self.coords["x"] = event.x
        self.coords["y"] = event.y

        # create a line on this point and store it in the list
        line = self.lines.append(self.canvas.create_line(self.coords["x"], self.coords["y"], self.coords["x"], self.coords["y"], width=5, fill='red'))

    def drag(self, event):
        # update the coordinates from the event
        self.coords["x2"] = event.x
        self.coords["y2"] = event.y

        # Change the coordinates of the last created line to the new coordinates
        line = self.canvas.coords(self.lines[-1], self.coords["x"], self.coords["y"], self.coords["x2"], self.coords["y2"])
        self.canvas.itemconfigure(line, fill="black")

if __name__ == "__main__":
    root = tk.Tk()
    app = MovableTextApp(root)
    root.mainloop()

# %%
import tkinter as tk
from PIL import ImageTk

class MovableTextBox:
    def __init__(self, canvas, app, text="Move me!", x=50, y=50):
        self.canvas = canvas
        self.app = app
        self.text = text
        self.x = x
        self.y = y

        # Create text box on the canvas
        self.text_box = self.canvas.create_text(self.x, self.y, text=self.text, anchor="nw", tags="text_box")

        # Bind events for moving the text box
        self.canvas.tag_bind("text_box", "<B1-Motion>", self.on_drag)

        # Bind click event to track text box clicks
        self.canvas.tag_bind("text_box", "<Button-1>", self.on_click)

    def on_drag(self, event):
        # Update text box position on drag
        self.x = event.x
        self.y = event.y
        self.canvas.coords(self.text_box, self.x, self.y)

    def on_click(self, event):
        # If in connection mode, add the clicked text box to the connecting list
        if self.app.connect_on_click:
            self.app.connecting_text_boxes.append(self)

class MovableTextApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Movable Text App")

        # Create canvas
        self.canvas = tk.Canvas(root, width=600, height=400)
        self.canvas.pack(expand=tk.YES, fill=tk.BOTH)

        # Create a list to store movable text boxes
        self.text_boxes = []

        # Create a list to store connecting lines
        self.lines = []

        # Create buttons
        self.create_button = tk.Button(root, text="Create Movable Text Box", command=self.add_text_box)
        self.create_button.pack(pady=10)

        self.connect_button = tk.Button(root, text="Connect Text Boxes", command=self.toggle_connect_mode)
        self.connect_button.pack(pady=10)

        self.draw_lines_button = tk.Button(root, text="Draw Lines", command=self.toggle_draw_lines_mode)
        self.draw_lines_button.pack(pady=10)

        # Variable to track whether to connect text boxes on click
        self.connect_on_click = False

        # Variable to track text box clicks for connecting
        self.connecting_text_boxes = []

        # Variable to track whether to draw lines
        self.draw_lines_mode = False

        # Bind drawing events
        self.canvas.bind("<ButtonPress-1>", self.click)
        self.canvas.bind("<B1-Motion>", self.drag)

        # keep a reference to all lines by keeping them in a list
        self.coords = {"x": None, "y": 0, "x2": 0, "y2": 0}
        self.lines = []

    def add_text_box(self):
        # Create a new movable text box and add it to the list
        new_text_box = MovableTextBox(self.canvas, self, text="Move me!", x=50, y=50)
        self.text_boxes.append(new_text_box)

    def toggle_connect_mode(self):
        # Toggle the flag to connect text boxes on click
        self.connect_on_click = not self.connect_on_click
        # Clear the list of connecting text boxes
        self.connecting_text_boxes = []

    def toggle_draw_lines_mode(self):
        # Toggle the flag to draw lines
        self.draw_lines_mode = not self.draw_lines_mode

    def draw_line(self):
        # Draw a line between the two clicked text boxes
        if len(self.connecting_text_boxes) == 2:
            text_box1 = self.connecting_text_boxes[0]
            text_box2 = self.connecting_text_boxes[1]

            x1, y1 = text_box1.x, text_box1.y
            x2, y2 = text_box2.x, text_box2.y
            line = self.canvas.create_line(x1, y1, x2, y2, fill="black")
            self.lines.append(line)

    def click(self, event):
        if self.draw_lines_mode:
            # define start point for line
            self.coords["x"] = event.x
            self.coords["y"] = event.y

            # create a line on this point and store it in the list
            line = self.lines.append(self.canvas.create_line(self.coords["x"], self.coords["y"], self.coords["x"], self.coords["y"], width=5, fill='red'))

    def drag(self, event):
        if self.draw_lines_mode:
            # update the coordinates from the event
            self.coords["x2"] = event.x
            self.coords["y2"] = event.y

            # Change the coordinates of the last created line to the new coordinates
            line = self.canvas.coords(self.lines[-1], self.coords["x"], self.coords["y"], self.coords["x2"], self.coords["y2"])
            self.canvas.itemconfigure(line, fill="black")

if __name__ == "__main__":
    root = tk.Tk()
    app = MovableTextApp(root)
    root.mainloop()

# %%
import tkinter as tk

class MovableTextBox:
    def __init__(self, canvas, app, text="Move me!", x=50, y=50):
        self.canvas = canvas
        self.app = app
        self.text = text
        self.x = x
        self.y = y

        # Create text box on the canvas
        self.text_box = self.canvas.create_text(self.x, self.y, text=self.text, anchor="nw", tags="text_box")

        # Bind events for moving the text box
        self.canvas.tag_bind("text_box", "<B1-Motion>", self.on_drag)

    def on_drag(self, event):
        # Update text box position on drag
        self.x = event.x
        self.y = event.y
        self.canvas.coords(self.text_box, self.x, self.y)

class MovableTextApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Movable Text App")

        # Create canvas
        self.canvas = tk.Canvas(root, width=600, height=400)
        self.canvas.pack(expand=tk.YES, fill=tk.BOTH)

        # Create a list to store movable text boxes
        self.text_boxes = []

        # Create a list to store connecting lines
        self.lines = []

        # Create buttons
        self.create_button = tk.Button(root, text="Create Movable Text Box", command=self.add_text_box)
        self.create_button.pack(pady=10)

        self.draw_lines_button = tk.Button(root, text="Draw Lines", command=self.toggle_draw_lines_mode)
        self.draw_lines_button.pack(pady=10)

        # Variable to track whether to draw lines
        self.draw_lines_mode = False

        # Bind drawing events
        self.canvas.bind("<ButtonPress-1>", self.click)
        self.canvas.bind("<B1-Motion>", self.drag)

        # keep a reference to all lines by keeping them in a list
        self.coords = {"x": None, "y": 0, "x2": 0, "y2": 0}
        self.lines = []

    def add_text_box(self):
        # Create a new movable text box and add it to the list
        new_text_box = MovableTextBox(self.canvas, self, text="Move me!", x=50, y=50)
        self.text_boxes.append(new_text_box)

    def toggle_draw_lines_mode(self):
        # Toggle the flag to draw lines
        self.draw_lines_mode = not self.draw_lines_mode

    def draw_line(self):
        x1, y1 = text_box1.x, text_box1.y
        x2, y2 = text_box2.x, text_box2.y
        line = self.canvas.create_line(x1, y1, x2, y2, fill="black")
        self.lines.append(line)

    def click(self, event):
        if self.draw_lines_mode:
            # define start point for line
            self.coords["x"] = event.x
            self.coords["y"] = event.y

            # create a line on this point and store it in the list
            line = self.lines.append(self.canvas.create_line(self.coords["x"], self.coords["y"], self.coords["x"], self.coords["y"], width=5, fill='red'))

    def drag(self, event):
        if self.draw_lines_mode:
            # update the coordinates from the event
            self.coords["x2"] = event.x
            self.coords["y2"] = event.y

            # Change the coordinates of the last created line to the new coordinates
            line = self.canvas.coords(self.lines[-1], self.coords["x"], self.coords["y"], self.coords["x2"], self.coords["y2"])
            self.canvas.itemconfigure(line, fill="black")

if __name__ == "__main__":
    root = tk.Tk()
    app = MovableTextApp(root)
    root.mainloop()

# %%
import tkinter as tk

class MovableTextBox:
    def __init__(self, canvas, app, text="Move me!", x=50, y=50):
        self.canvas = canvas
        self.app = app
        self.text = text
        self.x = x
        self.y = y

        # Create text box on the canvas
        self.text_box = self.canvas.create_text(self.x, self.y, text=self.text, anchor="nw", tags="text_box")

        # Bind events for moving the text box
        self.canvas.tag_bind("text_box", "<B1-Motion>", self.on_drag)
        self.canvas.tag_bind("text_box", "<Button-1>", self.on_click)

    def on_drag(self, event):
        # Update position of the clicked text box on drag
        if self.app.move_text_box_mode and self.app.clicked_text_box == self:
            self.x = event.x
            self.y = event.y
            self.canvas.coords(self.text_box, self.x, self.y)

    def on_click(self, event):
        # Set the clicked text box in the app
        self.app.clicked_text_box = self

class MovableTextApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Movable Text App")

        # Create canvas
        self.canvas = tk.Canvas(root, width=600, height=400)
        self.canvas.pack(expand=tk.YES, fill=tk.BOTH)

        # Create a list to store movable text boxes
        self.text_boxes = []

        # Create a list to store connecting lines
        self.lines = []

        # Create buttons
        self.create_button = tk.Button(root, text="Create Movable Text Box", command=self.add_text_box)
        self.create_button.pack(pady=10)

        self.draw_lines_button = tk.Button(root, text="Draw Lines", command=self.toggle_draw_lines_mode)
        self.draw_lines_button.pack(pady=10)

        self.move_text_box_button = tk.Button(root, text="Move Text Box", command=self.toggle_move_text_box_mode)
        self.move_text_box_button.pack(pady=10)

        # Variable to track whether to draw lines
        self.draw_lines_mode = False

        # Variable to track whether to move text boxes
        self.move_text_box_mode = False

        # Variable to track the clicked text box
        self.clicked_text_box = None

        # Bind drawing events
        self.canvas.bind("<ButtonPress-1>", self.click)
        self.canvas.bind("<B1-Motion>", self.drag)

        # keep a reference to all lines by keeping them in a list
        self.coords = {"x": None, "y": 0, "x2": 0, "y2": 0}
        self.lines = []

    def add_text_box(self):
        # Create a new movable text box and add it to the list
        new_text_box = MovableTextBox(self.canvas, self, text="Move me!", x=50, y=50)
        self.text_boxes.append(new_text_box)

    def toggle_draw_lines_mode(self):
        # Toggle the flag to draw lines
        self.draw_lines_mode = not self.draw_lines_mode

    def toggle_move_text_box_mode(self):
        # Toggle the flag to move text boxes
        self.move_text_box_mode = not self.move_text_box_mode

    def draw_line(self):
        x1, y1 = text_box1.x, text_box1.y
        x2, y2 = text_box2.x, text_box2.y
        line = self.canvas.create_line(x1, y1, x2, y2, fill="black")
        self.lines.append(line)

    def click(self, event):
        if self.draw_lines_mode:
            # define start point for line
            self.coords["x"] = event.x
            self.coords["y"] = event.y

            # create a line on this point and store it in the list
            line = self.lines.append(self.canvas.create_line(self.coords["x"], self.coords["y"], self.coords["x"], self.coords["y"], width=5, fill='red'))

    def drag(self, event):
        if self.draw_lines_mode:
            # update the coordinates from the event
            self.coords["x2"] = event.x
            self.coords["y2"] = event.y

            # Change the coordinates of the last created line to the new coordinates
            line = self.canvas.coords(self.lines[-1], self.coords["x"], self.coords["y"], self.coords["x2"], self.coords["y2"])
            self.canvas.itemconfigure(line, fill="black")

if __name__ == "__main__":
    root = tk.Tk()
    app = MovableTextApp(root)
    root.mainloop()

# %%
import tkinter as tk

class MovableTextBox:
    def __init__(self, canvas, app, text="Move me!", x=50, y=50):
        self.canvas = canvas
        self.app = app
        self.text = text
        self.x = x
        self.y = y

        # Create text box on the canvas
        self.text_box = self.canvas.create_text(self.x, self.y, text=self.text, anchor="nw", tags="text_box")

        # Bind events for moving the text box
        self.canvas.tag_bind("text_box", "<B1-Motion>", self.on_drag)
        self.canvas.tag_bind("text_box", "<Button-1>", self.on_click)

    def on_drag(self, event):
        # Update position of the clicked text box on drag
        if self.app.move_text_box_mode and self.app.clicked_text_box == self:
            self.x = event.x
            self.y = event.y
            self.canvas.coords(self.text_box, self.x, self.y)

    def on_click(self, event):
        # Set the clicked text box in the app
        self.app.clicked_text_box = self

class MovableTextApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Movable Text App")

        # Create canvas
        self.canvas = tk.Canvas(root, width=600, height=400)
        self.canvas.pack(expand=tk.YES, fill=tk.BOTH)

        # Create a list to store movable text boxes
        self.text_boxes = []

        # Create a list to store connecting lines
        self.lines = []

        # Create buttons
        self.create_button = tk.Button(root, text="Create Movable Text Box", command=self.add_text_box)
        self.create_button.pack(pady=10)

        self.move_text_box_button = tk.Button(root, text="Move Text Box", command=self.toggle_move_text_box_mode)
        self.move_text_box_button.pack(pady=10)

        self.draw_lines_button = tk.Button(root, text="Draw Lines", command=self.toggle_draw_lines_mode)
        self.draw_lines_button.pack(pady=10)

        # Variable to track whether to draw lines
        self.draw_lines_mode = False

        # Variable to track whether to move text boxes
        self.move_text_box_mode = False

        # Variable to track the clicked text box
        self.clicked_text_box = None

        # Bind drawing events
        self.canvas.bind("<ButtonPress-1>", self.click)
        self.canvas.bind("<B1-Motion>", self.drag)

        # keep a reference to all lines by keeping them in a list
        self.coords = {"x": None, "y": 0, "x2": 0, "y2": 0}
        self.lines = []

    def add_text_box(self):
        # Create a new movable text box and add it to the list
        new_text_box = MovableTextBox(self.canvas, self, text="Move me!", x=50, y=50)
        self.text_boxes.append(new_text_box)

    def toggle_draw_lines_mode(self):
        # Toggle the flag to draw lines
        self.draw_lines_mode = not self.draw_lines_mode

    def toggle_move_text_box_mode(self):
        # Toggle the flag to move text boxes
        self.move_text_box_mode = not self.move_text_box_mode

    def draw_line(self):
        x1, y1 = text_box1.x, text_box1.y
        x2, y2 = text_box2.x, text_box2.y
        line = self.canvas.create_line(x1, y1, x2, y2, fill="black")
        self.lines.append(line)

    def click(self, event):
        if self.draw_lines_mode:
            # define start point for line
            self.coords["x"] = event.x
            self.coords["y"] = event.y

            # create a line on this point and store it in the list
            line = self.lines.append(self.canvas.create_line(self.coords["x"], self.coords["y"], self.coords["x"], self.coords["y"], width=5, fill='red'))

    def drag(self, event):
        if self.draw_lines_mode:
            # update the coordinates from the event
            self.coords["x2"] = event.x
            self.coords["y2"] = event.y

            # Change the coordinates of the last created line to the new coordinates
            line = self.canvas.coords(self.lines[-1], self.coords["x"], self.coords["y"], self.coords["x2"], self.coords["y2"])
            self.canvas.itemconfigure(line, fill="black")

if __name__ == "__main__":
    root = tk.Tk()
    app = MovableTextApp(root)
    root.mainloop()

# %%
import tkinter as tk

class MovableTextBox:
    def __init__(self, canvas, app, text="Type here!", x=50, y=50, allow_rename=True):
        self.canvas = canvas
        self.app = app
        self.text = text
        self.x = x
        self.y = y
        self.allow_rename = allow_rename

        # Create Entry widget for text input
        self.text_entry = tk.Entry(self.canvas, state='normal' if allow_rename else 'disabled')
        self.text_entry.insert(0, self.text)
        self.text_entry.place(x=self.x, y=self.y)

        # Bind events for moving the text box, updating the text, and renaming
        self.text_entry.bind("<B1-Motion>", self.on_drag)
        self.text_entry.bind("<FocusIn>", self.on_focus_in)
        self.text_entry.bind("<FocusOut>", self.on_focus_out)

    def on_drag(self, event):
        # Update position of the clicked text box on drag
        if self.app.move_text_box_mode and self.app.clicked_text_box == self:
            self.x = event.x
            self.y = event.y
            self.text_entry.place(x=self.x, y=self.y)

    def on_focus_in(self, event):
        # Set the clicked text box in the app
        if self.allow_rename:
            self.app.clicked_text_box = self

    def on_focus_out(self, event):
        # Update the text when focus is lost
        if self.allow_rename:
            self.text = self.text_entry.get()

class MovableTextApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Movable Text App")

        # Create canvas
        self.canvas = tk.Canvas(root, width=600, height=400)
        self.canvas.pack(expand=tk.YES, fill=tk.BOTH)

        # Create a list to store movable text boxes
        self.text_boxes = []

        # Create buttons
        self.create_button = tk.Button(root, text="Create Movable Text Box", command=self.add_text_box)
        self.create_button.pack(pady=10)

        self.move_text_box_button = tk.Button(root, text="Move Text Box", command=self.toggle_move_text_box_mode)
        self.move_text_box_button.pack(pady=10)

        self.draw_lines_button = tk.Button(root, text="Draw Lines", command=self.toggle_draw_lines_mode)
        self.draw_lines_button.pack(pady=10)

        # Variable to track whether to draw lines
        self.draw_lines_mode = False

        # Variable to track whether to move text boxes
        self.move_text_box_mode = False

        # Variable to track the clicked text box
        self.clicked_text_box = None

        # Bind drawing events
        self.canvas.bind("<ButtonPress-1>", self.click)
        self.canvas.bind("<B1-Motion>", self.drag)

        # keep a reference to all lines by keeping them in a list
        self.coords = {"x": None, "y": 0, "x2": 0, "y2": 0}
        self.lines = []

    def add_text_box(self):
        # Create a new movable text box and add it to the list
        new_text_box = MovableTextBox(self.canvas, self, text="Type here!", x=50, y=50, allow_rename=True)
        self.text_boxes.append(new_text_box)

    def toggle_draw_lines_mode(self):
        # Toggle the flag to draw lines
        self.draw_lines_mode = not self.draw_lines_mode

    def toggle_move_text_box_mode(self):
        # Toggle the flag to move text boxes
        self.move_text_box_mode = not self.move_text_box_mode
        # Disable rename mode when moving text boxes
        self.rename_text_box_mode = False

    def draw_line(self):
        x1, y1 = text_box1.x, text_box1.y
        x2, y2 = text_box2.x, text_box2.y
        line = self.canvas.create_line(x1, y1, x2, y2, fill="black")
        self.lines.append(line)

    def click(self, event):
        if self.draw_lines_mode:
            # define start point for line
            self.coords["x"] = event.x
            self.coords["y"] = event.y

            # create a line on this point and store it in the list
            line = self.lines.append(self.canvas.create_line(self.coords["x"], self.coords["y"], self.coords["x"], self.coords["y"], width=5, fill='red'))

    def drag(self, event):
        if self.draw_lines_mode:
            # update the coordinates from the event
            self.coords["x2"] = event.x
            self.coords["y2"] = event.y

            # Change the coordinates of the last created line to the new coordinates
            line = self.canvas.coords(self.lines[-1], self.coords["x"], self.coords["y"], self.coords["x2"], self.coords["y2"])
            self.canvas.itemconfigure(line, fill="black")

if __name__ == "__main__":
    root = tk.Tk()
    app = MovableTextApp(root)
    root.mainloop()

# %%
import tkinter as tk

class MovableTextBox:
    def __init__(self, canvas, app, text="Worker type", x=50, y=50):
        self.canvas = canvas
        self.app = app
        self.text = text
        self.x = x
        self.y = y

        # Create text box on the canvas
        self.text_box = self.canvas.create_text(self.x, self.y, text=self.text, anchor="nw", tags="text_box")

        # Bind events for moving the text box
        self.canvas.tag_bind("text_box", "<B1-Motion>", self.on_drag)
        self.canvas.tag_bind("text_box", "<Button-1>", self.on_click)

    def on_drag(self, event):
        # Update position of the clicked text box on drag
        if self.app.move_text_box_mode and self.app.clicked_text_box == self:
            self.x = event.x
            self.y = event.y
            self.canvas.coords(self.text_box, self.x, self.y)

    def on_click(self, event):
        # Set the clicked text box in the app
        self.app.clicked_text_box = self

class MovableTextApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Company hierarchy")

        # Create canvas
        self.canvas = tk.Canvas(root, width=1400, height=600)
        self.canvas.pack(expand=tk.YES, fill=tk.BOTH)

        # Create a list to store movable text boxes
        self.text_boxes = []

        # Create a list to store connecting lines
        self.lines = []

        # Create buttons
        self.create_button = tk.Button(root, text="Create Movable Text Box", command=self.add_text_box)
        self.create_button.pack(pady=10)

        self.move_text_box_button = tk.Button(root, text="Move Text Box", command=self.toggle_move_text_box_mode)
        self.move_text_box_button.pack(pady=10)

        self.draw_lines_button = tk.Button(root, text="Draw Lines", command=self.toggle_draw_lines_mode)
        self.draw_lines_button.pack(pady=10)

        # Variable to track whether to draw lines
        self.draw_lines_mode = False

        # Variable to track whether to move text boxes
        self.move_text_box_mode = False

        # Variable to track the clicked text box
        self.clicked_text_box = None

        # Bind drawing events
        self.canvas.bind("<ButtonPress-1>", self.click)
        self.canvas.bind("<B1-Motion>", self.drag)

        # keep a reference to all arrows by keeping them in a list
        self.coords = {"x": None, "y": 0, "x2": 0, "y2": 0}
        self.arrows = []

    def add_text_box(self):
        # Create a new movable text box and add it to the list
        new_text_box = MovableTextBox(self.canvas, self, text="Worker type", x=50, y=50)
        self.text_boxes.append(new_text_box)

    def toggle_draw_lines_mode(self):
        # Toggle the flag to draw arrows
        self.draw_lines_mode = not self.draw_lines_mode

    def toggle_move_text_box_mode(self):
        # Toggle the flag to move text boxes
        self.move_text_box_mode = not self.move_text_box_mode
        # Disable rename mode when moving text boxes
        self.rename_text_box_mode = False

    def draw_arrow(self):
        x1, y1 = text_box1.x, text_box1.y
        x2, y2 = text_box2.x, text_box2.y
        arrow = self.canvas.create_line(x1, y1, x2, y2, arrow=tk.LAST, fill="black", width=2)
        self.arrows.append(arrow)

    def click(self, event):
        if self.draw_lines_mode:
            # define start point for arrow
            self.coords["x"] = event.x
            self.coords["y"] = event.y

            # create an arrow on this point and store it in the list
            arrow = self.arrows.append(self.canvas.create_line(self.coords["x"], self.coords["y"], self.coords["x"], self.coords["y"], arrow=tk.LAST, fill='red', width=2))

    def drag(self, event):
        if self.draw_lines_mode:
            # update the coordinates from the event
            self.coords["x2"] = event.x
            self.coords["y2"] = event.y

            # Change the coordinates of the last created arrow to the new coordinates
            arrow = self.canvas.coords(self.arrows[-1], self.coords["x"], self.coords["y"], self.coords["x2"], self.coords["y2"])
            self.canvas.itemconfigure(arrow, fill="black")

if __name__ == "__main__":
    root = tk.Tk()
    app = MovableTextApp(root)
    root.mainloop()
